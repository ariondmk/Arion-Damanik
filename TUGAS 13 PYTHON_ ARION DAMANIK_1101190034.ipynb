# %% [markdown]
# <a href="https://colab.research.google.com/github/ariondmk/Arion-Damanik/blob/main/TUGAS%2013%20PYTHON_%20ARION%20DAMANIK_1101190034.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def cos(frek,tipe,ht,hr,d):
    if frek in range(150,1501):
        Ca=69.55
        Cb=26.16
    elif frek in range(1501,2001):
        Ca=46.3
        Cb=33.9
    
    if tipe=='urban' :
        Cm=0
    elif tipe=='suburban' :
        Cm= -2*((np.log10((frek/28)**2))-5.4)
    elif tipe=='open' :
        Cm= -4.78*(np.log10(frek))+18.33*(np.log10(frek))-40.94
    else :
        Cm='tipe salah'
    
    ahr = (1.1*np.log10(frek)-0.7)*hr-(1.56*np.log10(frek)-1.8)
    Lp = Ca+(Cb*np.log10(frek))-(13.83*np.log(ht))-ahr+((44.9-6.55*np.log10(ht))*np.log10(d))-Cm
    
    return Lp

# %%
frekuensi=1800 #MHz
lokasi1='urban'
lokasi2='suburban'
lokasi3='open'
tower=80 #m
user=1.5 #m
dmin=200 #m
dmax=700 #m
X=200 #titik
d=np.random.randint(dmin,dmax,X)

# %%
print(d)
# Out:
# [204 271 381 324 424 407 450 243 511 603 475 400 609 640 586 218 436 255
#  541 606 251 538 275 467 486 289 259 347 426 389 511 640 498 227 203 436
#  646 696 224 466 589 552 588 527 323 267 310 291 468 252 606 360 437 469
#  468 362 323 334 614 599 293 538 536 586 556 262 549 461 244 429 335 361
#  223 655 527 282 465 202 580 355 591 202 365 562 525 325 561 365 674 358
#  230 357 610 300 248 235 335 590 224 383 664 690 229 519 580 228 381 593
#  290 592 220 311 301 694 233 310 483 387 472 400 239 645 220 224 431 228
#  208 553 521 613 239 483 673 565 599 564 665 628 330 604 331 381 437 416
#  646 692 624 213 568 218 606 325 217 481 263 233 399 578 589 466 306 434
#  583 640 481 557 551 687 499 341 226 647 482 604 280 654 614 268 552 268
#  484 400 475 236 625 546 271 330 536 306 371 496 674 244 542 388 418 441
#  649 592]

# %%
LpUrban=cos(frekuensi,lokasi1,tower,user,d)
LpSuburban=cos(frekuensi,lokasi2,tower,user,d)
LpOpen=cos(frekuensi,lokasi3,tower,user,d)

# %%
d_sort=d[np.argsort(d)]
Urban_sort=LpUrban[np.argsort(d)]
Suburban_sort=LpSuburban[np.argsort(d)]
Open_sort=LpOpen[np.argsort(d)]

# %% [markdown]
# # Bentuk Kurva

# %%
plt.figure()
plt.plot(d_sort,Urban_sort,'r-', label='Urban')
plt.plot(d_sort,Suburban_sort,'k-', label='Suburban')
plt.plot(d_sort,Open_sort,'g-', label='Open')
plt.legend()
plt.title('Frekuensi 1800 MHz')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()

# %% [markdown]
# # Grafik 2 - Model Urban

# %%
frekuensi=700 #MHz
frekuensi2=900 #MHz
frekuensi3=1800 #MHz
lokasi='urban'
tower=80 #m
user=1.5 #m
dmin=200 #m
dmax=700 #m
X=200 #titik
d=np.random.randint(dmin,dmax,X)

# %%
LpUrban=cos(frekuensi,lokasi,tower,user,d)
LpUrban2=cos(frekuensi2,lokasi,tower,user,d)
LpUrban3=cos(frekuensi3,lokasi,tower,user,d)

# %%
d_sort=d[np.argsort(d)]
Urban_sort=LpUrban[np.argsort(d)]
Urban2_sort=LpUrban2[np.argsort(d)]
Urban3_sort=LpUrban3[np.argsort(d)]

# %% [markdown]
# # Bentuk Kurva

# %%
plt.figure()
plt.plot(d_sort,Urban_sort,'r-', label='700 Mhz')
plt.plot(d_sort,Urban2_sort,'k-', label='900 Mhz')
plt.plot(d_sort,Urban3_sort,'g-', label='1800 Mhz')
plt.legend()
plt.title('Model Urban')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()
